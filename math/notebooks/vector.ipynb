# %%
import numpy as np

# %%
u = np.array([1., 2., 3.])
v = np.array([4., 5., 6.])

# %%
u + v
# Out:
# array([5., 7., 9.])

# %%
u - v
# Out:
# array([-3., -3., -3.])

# %%
v[0]
# Out:
# np.float64(4.0)

# %%
v[1]
# Out:
# np.float64(5.0)

# %%
2 * u
# Out:
# array([2., 4., 6.])

# %%
v / 3
# Out:
# array([1.33333333, 1.66666667, 2.        ])

# %%
np.linalg.norm(u)
# Out:
# np.float64(3.7416573867739413)
